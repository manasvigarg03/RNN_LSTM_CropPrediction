# %% [markdown]
# <a href="https://colab.research.google.com/github/manasvigarg03/RNN_LSTM_CropPrediction/blob/main/Crop_Humidity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(f'/content/drive/MyDrive/hyderabad.csv')

# %%
df.head()
# Out:
#              date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2009-01-01 00:00:00        28        15           0.0      8.7        6
# 1  2009-01-01 01:00:00        28        15           0.0      8.7        6
# 2  2009-01-01 02:00:00        28        15           0.0      8.7        6
# 3  2009-01-01 03:00:00        28        15           0.0      8.7        6
# 4  2009-01-01 04:00:00        28        15           0.0      8.7        6
#
#    uvIndex.1  moon_illumination  moonrise   moonset  ... WindChillC  \
# 0          1                 31  09:57 AM  09:58 PM  ...         21
# 1          1                 31  09:57 AM  09:58 PM  ...         20
# 2          1                 31  09:57 AM  09:58 PM  ...         20
# 3          1                 31  09:57 AM  09:58 PM  ...         19
# 4          1                 31  09:57 AM  09:58 PM  ...         21
#
#   WindGustKmph  cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# 0            9           0        83       0.0      1013     16          10
# 1            9           0        85       0.0      1013     16          10
# 2            8           0        86       0.0      1013     15          10
# 3            8           0        88       0.0      1013     15          10
# 4            7           0        80       0.0      1014     16          10
#
#    winddirDegree  windspeedKmph
# 0            150              6
# 1            148              5
# 2            147              5
# 3            145              5
# 4            148              5
#
# [5 rows x 25 columns]

# %%
features = ['maxtempC', 'mintempC', 'sunHour', 'humidity', 'precipMM' , 'pressure','tempC', 'windspeedKmph']
target = 'humidity'

# %%
X = df[features].values
y = df[target].values.reshape(-1, 1)

# %%
df[features].head()
# Out:
#    maxtempC  mintempC  sunHour  humidity  precipMM  pressure  tempC  \
# 0        28        15      8.7        83       0.0      1013     16
# 1        28        15      8.7        85       0.0      1013     16
# 2        28        15      8.7        86       0.0      1013     15
# 3        28        15      8.7        88       0.0      1013     15
# 4        28        15      8.7        80       0.0      1014     16
#
#    windspeedKmph
# 0              6
# 1              5
# 2              5
# 3              5
# 4              5

# %%
df = df.dropna(subset=["humidity"])
df=df.reset_index(drop=True)
training_set = df.iloc[::24,18:19].values

# %%
#Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X = []
y = []
n_future = 7 # next 14 days temperature forecast
n_past = 30 # Past 30 days
for i in range(0,len(training_set_scaled)-n_past-n_future+1):
    X.append(training_set_scaled[i : i + n_past , 0])
    y.append(training_set_scaled[i + n_past : i + n_past + n_future , 0 ])
X , y = np.array(X), np.array(y)
X = np.reshape(X, (X.shape[0] , X.shape[1], 1) )

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle = False)

# %%
from keras.models import Sequential
from keras.layers import LSTM,Dense ,Dropout
# Fitting RNN to training set using Keras Callbacks. Read Keras callbacks docs for more info.

# %%
from tensorflow.keras.layers import Bidirectional



regressor = Sequential()
regressor.add(Bidirectional(LSTM(units=15, return_sequences=True, input_shape = (X_train.shape[1],1) ) ))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units= 15 , return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units= 15 , return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units= 15))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = n_future,activation='linear'))
regressor.compile(optimizer='adam', loss='mean_squared_error',metrics=['acc'])
history = regressor.fit(X_train, y_train, epochs=20, batch_size=32, verbose=1, validation_split=0.1, shuffle = False)
# Out:
# Epoch 1/20
# 90/90 [==============================] - 24s 108ms/step - loss: 0.1623 - acc: 0.1458 - val_loss: 0.0405 - val_acc: 0.1160
# Epoch 2/20
# 90/90 [==============================] - 5s 58ms/step - loss: 0.0822 - acc: 0.1462 - val_loss: 0.0326 - val_acc: 0.1066
# Epoch 3/20
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0581 - acc: 0.1399 - val_loss: 0.0270 - val_acc: 0.1724
# Epoch 4/20
# 90/90 [==============================] - 5s 60ms/step - loss: 0.0502 - acc: 0.1364 - val_loss: 0.0260 - val_acc: 0.1097
# Epoch 5/20
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0445 - acc: 0.1486 - val_loss: 0.0251 - val_acc: 0.1755
# Epoch 6/20
# 90/90 [==============================] - 5s 59ms/step - loss: 0.0428 - acc: 0.1462 - val_loss: 0.0252 - val_acc: 0.1693
# Epoch 7/20
# 90/90 [==============================] - 6s 64ms/step - loss: 0.0398 - acc: 0.1577 - val_loss: 0.0252 - val_acc: 0.1129
# Epoch 8/20
# 90/90 [==============================] - 6s 71ms/step - loss: 0.0386 - acc: 0.1413 - val_loss: 0.0248 - val_acc: 0.1254
# Epoch 9/20
# 90/90 [==============================] - 5s 59ms/step - loss: 0.0372 - acc: 0.1378 - val_loss: 0.0250 - val_acc: 0.1442
# Epoch 10/20
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0363 - acc: 0.1410 - val_loss: 0.0245 - val_acc: 0.1787
# Epoch 11/20
# 90/90 [==============================] - 5s 59ms/step - loss: 0.0358 - acc: 0.1507 - val_loss: 0.0249 - val_acc: 0.1442
# Epoch 12/20
# 90/90 [==============================] - 6s 72ms/step - loss: 0.0336 - acc: 0.1298 - val_loss: 0.0249 - val_acc: 0.1850
# Epoch 13/20
# 90/90 [==============================] - 8s 85ms/step - loss: 0.0339 - acc: 0.1469 - val_loss: 0.0246 - val_acc: 0.1881
# Epoch 14/20
# 90/90 [==============================] - 6s 72ms/step - loss: 0.0324 - acc: 0.1382 - val_loss: 0.0243 - val_acc: 0.1850
# Epoch 15/20
# 90/90 [==============================] - 6s 65ms/step - loss: 0.0326 - acc: 0.1518 - val_loss: 0.0248 - val_acc: 0.1473
# Epoch 16/20
# 90/90 [==============================] - 5s 58ms/step - loss: 0.0319 - acc: 0.1486 - val_loss: 0.0246 - val_acc: 0.2194
# Epoch 17/20
# 90/90 [==============================] - 7s 77ms/step - loss: 0.0315 - acc: 0.1622 - val_loss: 0.0244 - val_acc: 0.2006
# Epoch 18/20
# 90/90 [==============================] - 5s 60ms/step - loss: 0.0310 - acc: 0.1549 - val_loss: 0.0243 - val_acc: 0.1944
# Epoch 19/20
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0304 - acc: 0.1486 - val_loss: 0.0244 - val_acc: 0.1661
# Epoch 20/20
# 90/90 [==============================] - 5s 59ms/step - loss: 0.0300 - acc: 0.1465 - val_loss: 0.0245 - val_acc: 0.2163

# %%
import matplotlib.pyplot as plt


# Plot training loss vs validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# Assuming y_true contains the true target values and y_pred contains the predicted target values
predicted_temperature = regressor.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, predicted_temperature))
print("RMSE:", rmse)
# Out:
# 25/25 [==============================] - 3s 16ms/step
# RMSE: 0.13052701735425298

# %%
predicted_temperature = sc.inverse_transform(predicted_temperature)
y_test = sc.inverse_transform(y_test)

# %%
import matplotlib.pyplot as plt

# Assuming y_test contains the true target values and y_pred contains the predicted target values
plt.figure(figsize=(50, 25))
plt.plot(y_test.flatten(), label='Actual')
plt.plot(predicted_temperature.flatten(), label='Predicted')
plt.title('Actual vs Predicted')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
